# %% [markdown]
# <a href="https://colab.research.google.com/github/statrav/pages/blob/main/Ch2_1_Priority_Queue_and_Heap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. Implementation and performance of Priority Queue

# %% [markdown]
# - Priority가 있는 element는 순서를 무시하고 선행됨

# %% [markdown]
# 1. Lazy approach : 순서가 없는 실행
#     - enqueue event : 단순 insert
#     - dequeue event : Highest priority 를 찾아서 element를 remove
# 2. Early-bird approach : 순서가 있는 실행
#     - enqueue event : 순서대로 insert
#     - dequeue event : 순서 상 가장 첫 번째 것을 remove

# %% [markdown]
# [Implementation of priority queues]
#
# - Sorted : Enqueue(node, priority)
#
# - Enqueue = Insert
# - Dequeue = Delete Highest Priority
# - FindMax = Find Highest Priority

# %% [markdown]
# # 02. Balanced Tree

# %% [markdown]
# [Balanced Tree]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# → Balanced Tree가 되려면 정삼각형의 모양을 가져야 하며, 위의 Unbalanced Tree 예시에서 Balanced가 되려면 Node 31개가 필요
#
# - Complete tree → balanced tree O
# - balanced tree → Complete tree X (왼쪽부터 채워져야 함)

# %% [markdown]
# # 03. Binary heap

# %% [markdown]
# [Binary heap for priority queue]
#
# - binary tree (left side와 right side가 있음) 중 2개의 property를 가지는 것
#     - 모양 : Complete tree여야 함
#     - Max heap의 전제조건 : 각각의 parent 노드가 children보다 크거나 같아야 함 (더 높은 값을 가져야 함)
#     - Min heap의 전제조건 : Max heap의 반대 (낮은 값)

# %% [markdown]
# [Is this tree a max-heap?]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 04. Implementation of insert of binary heap

# %% [markdown]
# ['70'이라는 element를 input한다면? → input은 항상 끝에]
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 05. Delete operation of binary heap

# %% [markdown]
# [Binary Heap 구조에서 Delete를 한다면 무조건 가장 큰 값부터 지워짐 → 가장 큰 값은 Root에 있음]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 06. Heap sort

# %% [markdown]
# 1. Heap으로 insert 하여 print
# 2. 하나하나 element 모두 take out (꺼내오기) 로 sorting
